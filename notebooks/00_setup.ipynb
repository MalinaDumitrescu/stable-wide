# %% [markdown]
# # Setup
#
# Short environment check

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from stablewide.notebook_utils import find_project_root, run_experiment, read_outputs, core_subsample_table
ROOT = find_project_root(ROOT)
print(ROOT)
# Out:
# C:\Users\scoti\PycharmProjects\STABLE_WIDE_FINAL

# %%
import sys, platform
print(sys.version)
print(platform.platform())
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# Windows-10-10.0.26200-SP0

# %%
packages = ["numpy", "pandas", "scipy", "sklearn", "matplotlib", "torch", "tabpfnwide"]
for name in packages:
    try:
        mod = __import__(name)
        print(f"{name:12s} OK  {getattr(mod, '__version__', '')}")
    except Exception as e:
        print(f"{name:12s} missing / unavailable: {type(e).__name__}")
# Out:
# numpy        OK  2.4.6
# pandas       OK  3.0.6
# scipy        OK  1.17.1
# sklearn      OK  1.9.1
# matplotlib   OK  3.11.2
# torch        OK  2.5.1+cu121
# tabpfnwide   OK

# %%
try:
    import torch
    print("CUDA:", torch.cuda.is_available())
    if torch.cuda.is_available():
        print(torch.cuda.get_device_name(0))
except Exception:
    pass
# Out:
# CUDA: True
# NVIDIA GeForce RTX 3050 Laptop GPU
